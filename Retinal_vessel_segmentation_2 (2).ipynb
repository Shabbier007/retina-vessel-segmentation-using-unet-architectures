# %%
from tensorflow.keras import models, layers, regularizers
from tensorflow.keras import backend as K


#convolutional block
def conv_block(x, kernelsize, filters, dropout, batchnorm=False): 
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(x)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    if dropout > 0:
        conv = layers.Dropout(dropout)(conv)
    conv = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding="same")(conv)
    if batchnorm is True:
        conv = layers.BatchNormalization(axis=3)(conv)
    conv = layers.Activation("relu")(conv)
    return conv


#residual convolutional block
def res_conv_block(x, kernelsize, filters, dropout, batchnorm=False):
    conv1 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        conv1 = layers.BatchNormalization(axis=3)(conv1)
    conv1 = layers.Activation('relu')(conv1)    
    conv2 = layers.Conv2D(filters, (kernelsize, kernelsize), kernel_initializer='he_normal', padding='same')(conv1)
    if batchnorm is True:
        conv2 = layers.BatchNormalization(axis=3)(conv2)
        conv2 = layers.Activation("relu")(conv2)
    if dropout > 0:
        conv2 = layers.Dropout(dropout)(conv2)
        
    #skip connection    
    shortcut = layers.Conv2D(filters, kernel_size=(1, 1), kernel_initializer='he_normal', padding='same')(x)
    if batchnorm is True:
        shortcut = layers.BatchNormalization(axis=3)(shortcut)
    shortcut = layers.Activation("relu")(shortcut)
    respath = layers.add([shortcut, conv2])       
    return respath


#gating signal for attention unit
def gatingsignal(input, out_size, batchnorm=False):
    x = layers.Conv2D(out_size, (1, 1), padding='same')(input)
    if batchnorm:
        x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    return x

#attention unit/block based on soft attention
def attention_block(x, gating, inter_shape):
    shape_x = K.int_shape(x)
    shape_g = K.int_shape(gating)
    theta_x = layers.Conv2D(inter_shape, (2, 2), strides=(2, 2), kernel_initializer='he_normal', padding='same')(x) 
    shape_theta_x = K.int_shape(theta_x)
    phi_g = layers.Conv2D(inter_shape, (1, 1), kernel_initializer='he_normal', padding='same')(gating)
    upsample_g = layers.Conv2DTranspose(inter_shape, (3, 3), strides=(shape_theta_x[1] // shape_g[1], shape_theta_x[2] // shape_g[2]), kernel_initializer='he_normal', padding='same')(phi_g)
    concat_xg = layers.add([upsample_g, theta_x])
    act_xg = layers.Activation('relu')(concat_xg)
    psi = layers.Conv2D(1, (1, 1), kernel_initializer='he_normal', padding='same')(act_xg)
    sigmoid_xg = layers.Activation('sigmoid')(psi)
    shape_sigmoid = K.int_shape(sigmoid_xg)
    upsample_psi = layers.UpSampling2D(size=(shape_x[1] // shape_sigmoid[1], shape_x[2] // shape_sigmoid[2]))(sigmoid_xg) 
    upsample_psi = layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3), arguments={'repnum': shape_x[3]})(upsample_psi)                          
    y = layers.multiply([upsample_psi, x])
    result = layers.Conv2D(shape_x[3], (1, 1), kernel_initializer='he_normal', padding='same')(y)
    attenblock = layers.BatchNormalization()(result)
    return attenblock

#Simple U-NET
def unetmodel(input_shape, dropout=0.2, batchnorm=True):    
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    

    # Downsampling layers
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers   
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, dn_4], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, dn_3], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
       
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, dn_2], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, dn_1], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)    
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()        
    return model

    
#Attention U-NET
def attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool_1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)
    
    dn_2 = conv_block(pool_1, kernelsize, filters[1], dropout, batchnorm)
    pool_2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)
    
    dn_3 = conv_block(pool_2, kernelsize, filters[2], dropout, batchnorm)
    pool_3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)
    
    dn_4 = conv_block(pool_3, kernelsize, filters[3], dropout, batchnorm)
    pool_4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)
    
    dn_5 = conv_block(pool_4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
    
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()       
    return model    

#Res-UNET
def residualunet(input_shape, dropout=0.2, batchnorm=True):

    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2

    inputs = layers.Input(input_shape) 

    # Downsampling layers    
    dn_conv1 = conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    dn_pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv1)

    dn_conv2 = res_conv_block(dn_pool1, kernelsize, filters[1], dropout, batchnorm)
    dn_pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv2)

    dn_conv3 = res_conv_block(dn_pool2, kernelsize, filters[2], dropout, batchnorm)
    dn_pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv3)

    dn_conv4 = res_conv_block(dn_pool3, kernelsize, filters[3], dropout, batchnorm)
    dn_pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_conv4)

    dn_conv5 = res_conv_block(dn_pool4, kernelsize, filters[4], dropout, batchnorm)
   
    # upsampling layers
    up_conv6 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_conv5)
    up_conv6 = layers.concatenate([up_conv6, dn_conv4], axis=3)
    up_conv6 = res_conv_block(up_conv6, kernelsize, filters[3], dropout, batchnorm)

    up_conv7 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv6)
    up_conv7 = layers.concatenate([up_conv7, dn_conv3], axis=3)
    up_conv7 = res_conv_block(up_conv7, kernelsize, filters[2], dropout, batchnorm)

    up_conv8 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv7)
    up_conv8 = layers.concatenate([up_conv8, dn_conv2], axis=3)
    up_conv8 = res_conv_block(up_conv8, kernelsize, filters[1], dropout, batchnorm)

    up_conv9 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv8)
    up_conv9 = layers.concatenate([up_conv9, dn_conv1], axis=3)
    up_conv9 = res_conv_block(up_conv9, kernelsize, filters[0], dropout, batchnorm)


    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv9)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final) 
    
    model = models.Model(inputs=[inputs], outputs=[outputs])
    model.summary()
    return model

#Residual-Attention UNET (RA-UNET)
def residual_attentionunet(input_shape, dropout=0.2, batchnorm=True):
    
    filters = [16, 32, 64, 128, 256]
    kernelsize = 3
    upsample_size = 2
    
    inputs = layers.Input(input_shape)    
    
    # Downsampling layers
    dn_1 = res_conv_block(inputs, kernelsize, filters[0], dropout, batchnorm)
    pool1 = layers.MaxPooling2D(pool_size=(2,2))(dn_1)

    dn_2 = res_conv_block(pool1, kernelsize, filters[1], dropout, batchnorm)
    pool2 = layers.MaxPooling2D(pool_size=(2,2))(dn_2)

    dn_3 = res_conv_block(pool2, kernelsize, filters[2], dropout, batchnorm)
    pool3 = layers.MaxPooling2D(pool_size=(2,2))(dn_3)

    dn_4 = res_conv_block(pool3, kernelsize, filters[3], dropout, batchnorm)
    pool4 = layers.MaxPooling2D(pool_size=(2,2))(dn_4)

    dn_5 = res_conv_block(pool4, kernelsize, filters[4], dropout, batchnorm)

    # Upsampling layers    
    gating_5 = gatingsignal(dn_5, filters[3], batchnorm)
    att_5 = attention_block(dn_4, gating_5, filters[3])
    up_5 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(dn_5)
    up_5 = layers.concatenate([up_5, att_5], axis=3)
    up_conv_5 = res_conv_block(up_5, kernelsize, filters[3], dropout, batchnorm)
    
    gating_4 = gatingsignal(up_conv_5, filters[2], batchnorm)
    att_4 = attention_block(dn_3, gating_4, filters[2])
    up_4 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_5)
    up_4 = layers.concatenate([up_4, att_4], axis=3)
    up_conv_4 = res_conv_block(up_4, kernelsize, filters[2], dropout, batchnorm)
   
    gating_3 = gatingsignal(up_conv_4, filters[1], batchnorm)
    att_3 = attention_block(dn_2, gating_3, filters[1])
    up_3 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_4)
    up_3 = layers.concatenate([up_3, att_3], axis=3)
    up_conv_3 = res_conv_block(up_3, kernelsize, filters[1], dropout, batchnorm)
    
    gating_2 = gatingsignal(up_conv_3, filters[0], batchnorm)
    att_2 = attention_block(dn_1, gating_2, filters[0])
    up_2 = layers.UpSampling2D(size=(upsample_size, upsample_size), data_format="channels_last")(up_conv_3)
    up_2 = layers.concatenate([up_2, att_2], axis=3)
    up_conv_2 = res_conv_block(up_2, kernelsize, filters[0], dropout, batchnorm)
   
    conv_final = layers.Conv2D(1, kernel_size=(1,1))(up_conv_2)
    conv_final = layers.BatchNormalization(axis=3)(conv_final)
    outputs = layers.Activation('sigmoid')(conv_final)  

    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    model.summary() 
    return model

# %%
# !pip install patchify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/dist-packages (from patchify) (1.22.4)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3

# %%
# !pip install tifffile 
# !pip install imagecodecs 
import numpy 
import tifffile as tiff
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tifffile in /usr/local/lib/python3.8/dist-packages (2022.10.10)
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.8/dist-packages (from tifffile) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.8/dist-packages (2022.9.26)
# Requirement already satisfied: numpy>=1.19.2 in /usr/local/lib/python3.8/dist-packages (from imagecodecs) (1.21.6)

# %% [markdown]
# ## Evaluation Metrics

# %%
from tensorflow.keras import backend as K
from sklearn.metrics import jaccard_score,confusion_matrix


def IoU_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

def IoU_loss(y_true, y_pred):
    return -IoU_coef(y_true, y_pred)
 
def dice_coef(y_true, y_pred):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2.0 * intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) + 1.0)
 
def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)
  
def accuracy(y_true, y_pred):
    cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
    acc = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1])
    return acc
  
def IoU(y_true, y_pred, labels = [0, 1]):
   IoU = []
   for label in labels:
      jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
      IoU.append(jaccard)     
   return np.mean(IoU)

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify
from PIL import Image
np.random.seed(0) 


#CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized


path1 = r'/content/drive/MyDrive/Dataset/DRIVE/training/images' #training images directory
path2 = r'/content/drive/MyDrive/Dataset/DRIVE/training/manual' #training masks directory

image_dataset = []
mask_dataset = [] 

patch_size = 512

images = sorted(os.listdir(path1)) 
for i, image_name in enumerate(images):  
   if image_name.endswith(".tif"):                   
       image = tiff.imread(path1+"/"+image_name)  #Read image
       image = image[:,:,1] #selecting green channel
       image = clahe_equalized(image) #applying CLAHE
       SIZE_X = (image.shape[1]//patch_size)*patch_size #getting size multiple of patch size
       SIZE_Y = (image.shape[0]//patch_size)*patch_size #getting size multiple of patch size
       image = Image.fromarray(image)        
       image = image.resize((SIZE_X, SIZE_Y)) #resize image       
       image = np.array(image) 
       patches_img = patchify(image, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
       for i in range(patches_img.shape[0]):
           for j in range(patches_img.shape[1]):                        
               single_patch_img = patches_img[i,j,:,:]                 
               single_patch_img = (single_patch_img.astype('float32')) / 255.                    
               image_dataset.append(single_patch_img)

masks = sorted(os.listdir(path2))  
for i, mask_name in enumerate(masks):  
    if mask_name.endswith(".gif"):                  
        mask = skimage.io.imread(path2+"/"+mask_name)   #Read masks
        SIZE_X = (mask.shape[1]//patch_size)*patch_size #getting size multiple of patch size
        SIZE_Y = (mask.shape[0]//patch_size)*patch_size #getting size multiple of patch size
        mask = Image.fromarray(mask)        
        mask = mask.resize((SIZE_X, SIZE_Y))  #resize image
        mask = np.array(mask)
        patches_mask = patchify(mask, (patch_size, patch_size), step=patch_size)  #create patches(patch_sizexpatch_sizex1)
            
        for i in range(patches_mask.shape[0]):
            for j in range(patches_mask.shape[1]):                            
                single_patch_mask = patches_mask[i,j,:,:]
                single_patch_mask = (single_patch_mask.astype('float32'))/255. 
                mask_dataset.append(single_patch_mask) 
 
image_dataset = np.array(image_dataset)
mask_dataset =  np.array(mask_dataset)
image_dataset = np.expand_dims(image_dataset,axis=-1)
mask_dataset =  np.expand_dims(mask_dataset,axis=-1)


#importing models
# from model import unetmodel, residualunet, attentionunet, residual_attentionunet
from tensorflow.keras.optimizers import Adam
# from evaluation_metrics import IoU_coef,IoU_loss

IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1
input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

# model = unetmodel(input_shape)
# model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])

#model = residualunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model = attentionunet(input_shape)
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
#model = attention_residualunet(input_shape)
#model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])


#splitting data into 70-30 ratio to validate training performance
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.3, random_state=0)

#train model
history = model.fit(x_train, y_train, 
                    verbose=1,
                    batch_size = 16,
                    validation_data=(x_test, y_test ), 
                    shuffle=False,
                    epochs=150)

#training-validation loss curve
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure(figsize=(7,5))
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

#training-validation accuracy curve
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
plt.figure(figsize=(7,5))
plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'y', label='Validation Accuracy')
plt.title('Training and validation accuracies')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#training-validation IoU curve
iou_coef = history.history['IoU_coef']
val_iou_coef = history.history['val_IoU_coef']
plt.figure(figsize=(7,5))
plt.plot(epochs, iou_coef, 'r', label='Training IoU')
plt.plot(epochs, val_iou_coef, 'y', label='Validation IoU')
plt.title('Training and validation IoU coefficients')
plt.xlabel('Epochs')
plt.ylabel('IoU')
plt.legend()
plt.show()

#save model
model.save('/content/drive/MyDrive/Dataset/new_data/files/attention_model_150_epochs.hdf5')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 512, 512, 16  160         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 512, 512, 16  64         ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  activation_19 (Activation)     (None, 512, 512, 16  0           ['batch_normalization_19[0][0]']
#                                 )
#
#  dropout_9 (Dropout)            (None, 512, 512, 16  0           ['activation_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_9[0][0]']
#                                 )
#
#  batch_normalization_20 (BatchN  (None, 512, 512, 16  64         ['conv2d_20[0][0]']
#  ormalization)                  )
#
#  activation_20 (Activation)     (None, 512, 512, 16  0           ['batch_normalization_20[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 256, 256, 16  0          ['activation_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 256, 256, 32  4640        ['max_pooling2d_4[0][0]']
#                                 )
#
#  batch_normalization_21 (BatchN  (None, 256, 256, 32  128        ['conv2d_21[0][0]']
#  ormalization)                  )
#
#  activation_21 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_21[0][0]']
#                                 )
#
#  dropout_10 (Dropout)           (None, 256, 256, 32  0           ['activation_21[0][0]']
#                                 )
#
#  conv2d_22 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_10[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 256, 256, 32  128        ['conv2d_22[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 128, 128, 32  0          ['activation_22[0][0]']
#                                 )
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_5[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 64  256        ['conv2d_23[0][0]']
#  ormalization)                  )
#
#  activation_23 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  dropout_11 (Dropout)           (None, 128, 128, 64  0           ['activation_23[0][0]']
#                                 )
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_11[0][0]']
#                                 )
#
#  batch_normalization_24 (BatchN  (None, 128, 128, 64  256        ['conv2d_24[0][0]']
#  ormalization)                  )
#
#  activation_24 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_24[0][0]']
#                                 )
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 64, 64, 64)  0           ['activation_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 64, 64, 128)  512        ['conv2d_25[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_25[0][0]']
#
#  dropout_12 (Dropout)           (None, 64, 64, 128)  0           ['activation_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_12[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 64, 64, 128)  512        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_26[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_27[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_27[0][0]']
#
#  dropout_13 (Dropout)           (None, 32, 32, 256)  0           ['activation_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 32, 32, 256)  590080      ['dropout_13[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 128)  32896       ['activation_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 32, 32, 128)  512        ['conv2d_29[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 32, 32, 128)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 32, 32, 128)  16512       ['activation_29[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 128)  147584     ['conv2d_31[0][0]']
#  ose)
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 128)  65664       ['activation_26[0][0]']
#
#  add (Add)                      (None, 32, 32, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  activation_30 (Activation)     (None, 32, 32, 128)  0           ['add[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 32, 32, 1)    129         ['activation_30[0][0]']
#
#  activation_31 (Activation)     (None, 32, 32, 1)    0           ['conv2d_32[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 1)   0           ['activation_31[0][0]']
#
#  lambda (Lambda)                (None, 64, 64, 128)  0           ['up_sampling2d_4[0][0]']
#
#  multiply (Multiply)            (None, 64, 64, 128)  0           ['lambda[0][0]',
#                                                                   'activation_26[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 128)  16512       ['multiply[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 256)  0          ['activation_28[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 64, 64, 128)  512        ['conv2d_33[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 64, 64, 384)  0           ['up_sampling2d_5[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 128)  442496      ['concatenate_4[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 64, 64, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_31[0][0]']
#
#  dropout_14 (Dropout)           (None, 64, 64, 128)  0           ['activation_32[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 64, 64, 128)  147584      ['dropout_14[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 128)  512        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 64, 64, 64)   8256        ['activation_33[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 64)  256         ['conv2d_36[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_33[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 64)   4160        ['activation_34[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  36928       ['conv2d_38[0][0]']
#  spose)
#
#  conv2d_37 (Conv2D)             (None, 64, 64, 64)   16448       ['activation_24[0][0]']
#
#  add_1 (Add)                    (None, 64, 64, 64)   0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  activation_35 (Activation)     (None, 64, 64, 64)   0           ['add_1[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 64, 1)    65          ['activation_35[0][0]']
#
#  activation_36 (Activation)     (None, 64, 64, 1)    0           ['conv2d_39[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 128, 128, 1)  0          ['activation_36[0][0]']
#
#  lambda_1 (Lambda)              (None, 128, 128, 64  0           ['up_sampling2d_6[0][0]']
#                                 )
#
#  multiply_1 (Multiply)          (None, 128, 128, 64  0           ['lambda_1[0][0]',
#                                 )                                 'activation_24[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 128, 128, 64  4160        ['multiply_1[0][0]']
#                                 )
#
#  up_sampling2d_7 (UpSampling2D)  (None, 128, 128, 12  0          ['activation_33[0][0]']
#                                 8)
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 64  256        ['conv2d_40[0][0]']
#  ormalization)                  )
#
#  concatenate_5 (Concatenate)    (None, 128, 128, 19  0           ['up_sampling2d_7[0][0]',
#                                 2)                                'batch_normalization_34[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 128, 128, 64  110656      ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 64  256        ['conv2d_41[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  dropout_15 (Dropout)           (None, 128, 128, 64  0           ['activation_37[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 128, 128, 64  36928       ['dropout_15[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 128, 128, 64  256        ['conv2d_42[0][0]']
#  ormalization)                  )
#
#  activation_38 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 32  2080        ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 128, 128, 32  128        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  activation_39 (Activation)     (None, 128, 128, 32  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 128, 128, 32  1056        ['activation_39[0][0]']
#                                 )
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 32  9248       ['conv2d_45[0][0]']
#  spose)                         )
#
#  conv2d_44 (Conv2D)             (None, 128, 128, 32  4128        ['activation_22[0][0]']
#                                 )
#
#  add_2 (Add)                    (None, 128, 128, 32  0           ['conv2d_transpose_2[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  activation_40 (Activation)     (None, 128, 128, 32  0           ['add_2[0][0]']
#                                 )
#
#  conv2d_46 (Conv2D)             (None, 128, 128, 1)  33          ['activation_40[0][0]']
#
#  activation_41 (Activation)     (None, 128, 128, 1)  0           ['conv2d_46[0][0]']
#
#  up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_41[0][0]']
#
#  lambda_2 (Lambda)              (None, 256, 256, 32  0           ['up_sampling2d_8[0][0]']
#                                 )
#
#  multiply_2 (Multiply)          (None, 256, 256, 32  0           ['lambda_2[0][0]',
#                                 )                                 'activation_22[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 32  1056        ['multiply_2[0][0]']
#                                 )
#
#  up_sampling2d_9 (UpSampling2D)  (None, 256, 256, 64  0          ['activation_38[0][0]']
#                                 )
#
#  batch_normalization_38 (BatchN  (None, 256, 256, 32  128        ['conv2d_47[0][0]']
#  ormalization)                  )
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 96  0           ['up_sampling2d_9[0][0]',
#                                 )                                 'batch_normalization_38[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 256, 256, 32  27680       ['concatenate_6[0][0]']
#                                 )
#
#  batch_normalization_39 (BatchN  (None, 256, 256, 32  128        ['conv2d_48[0][0]']
#  ormalization)                  )
#
#  activation_42 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_39[0][0]']
#                                 )
#
#  dropout_16 (Dropout)           (None, 256, 256, 32  0           ['activation_42[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 256, 256, 32  9248        ['dropout_16[0][0]']
#                                 )
#
#  batch_normalization_40 (BatchN  (None, 256, 256, 32  128        ['conv2d_49[0][0]']
#  ormalization)                  )
#
#  activation_43 (Activation)     (None, 256, 256, 32  0           ['batch_normalization_40[0][0]']
#                                 )
#
#  conv2d_50 (Conv2D)             (None, 256, 256, 16  528         ['activation_43[0][0]']
#                                 )
#
#  batch_normalization_41 (BatchN  (None, 256, 256, 16  64         ['conv2d_50[0][0]']
#  ormalization)                  )
#
#  activation_44 (Activation)     (None, 256, 256, 16  0           ['batch_normalization_41[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 16  272         ['activation_44[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 16  2320       ['conv2d_52[0][0]']
#  spose)                         )
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 16  1040        ['activation_20[0][0]']
#                                 )
#
#  add_3 (Add)                    (None, 256, 256, 16  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_51[0][0]']
#
#  activation_45 (Activation)     (None, 256, 256, 16  0           ['add_3[0][0]']
#                                 )
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 1)  17          ['activation_45[0][0]']
#
#  activation_46 (Activation)     (None, 256, 256, 1)  0           ['conv2d_53[0][0]']
#
#  up_sampling2d_10 (UpSampling2D  (None, 512, 512, 1)  0          ['activation_46[0][0]']
#  )
#
#  lambda_3 (Lambda)              (None, 512, 512, 16  0           ['up_sampling2d_10[0][0]']
#                                 )
#
#  multiply_3 (Multiply)          (None, 512, 512, 16  0           ['lambda_3[0][0]',
#                                 )                                 'activation_20[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 512, 512, 16  272         ['multiply_3[0][0]']
#                                 )
#
#  up_sampling2d_11 (UpSampling2D  (None, 512, 512, 32  0          ['activation_43[0][0]']
#  )                              )
#
#  batch_normalization_42 (BatchN  (None, 512, 512, 16  64         ['conv2d_54[0][0]']
#  ormalization)                  )
#
#  concatenate_7 (Concatenate)    (None, 512, 512, 48  0           ['up_sampling2d_11[0][0]',
#                                 )                                 'batch_normalization_42[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 512, 512, 16  6928        ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_43 (BatchN  (None, 512, 512, 16  64         ['conv2d_55[0][0]']
#  ormalization)                  )
#
#  activation_47 (Activation)     (None, 512, 512, 16  0           ['batch_normalization_43[0][0]']
#                                 )
#
#  dropout_17 (Dropout)           (None, 512, 512, 16  0           ['activation_47[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 512, 512, 16  2320        ['dropout_17[0][0]']
#                                 )
#
#  batch_normalization_44 (BatchN  (None, 512, 512, 16  64         ['conv2d_56[0][0]']
#  ormalization)                  )
#
#  activation_48 (Activation)     (None, 512, 512, 16  0           ['batch_normalization_44[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 512, 512, 1)  17          ['activation_48[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 512, 512, 1)  4          ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 512, 512, 1)  0           ['batch_normalization_45[0][0]']
#
# ==================================================================================================
# Total params: 2,341,513
# Trainable params: 2,337,607
# Non-trainable params: 3,906
# __________________________________________________________________________________________________
# Epoch 1/150
# 1/1 [==============================] - 11s 11s/step - loss: -0.0817 - accuracy: 0.4821 - IoU_coef: 0.0817 - val_loss: -0.0890 - val_accuracy: 0.0465 - val_IoU_coef: 0.0890
# Epoch 2/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.0969 - accuracy: 0.5288 - IoU_coef: 0.0969 - val_loss: -0.0858 - val_accuracy: 0.0471 - val_IoU_coef: 0.0858
# Epoch 3/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1103 - accuracy: 0.5596 - IoU_coef: 0.1103 - val_loss: -0.0852 - val_accuracy: 0.0466 - val_IoU_coef: 0.0852
# Epoch 4/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1202 - accuracy: 0.6149 - IoU_coef: 0.1202 - val_loss: -0.0851 - val_accuracy: 0.0490 - val_IoU_coef: 0.0851
# Epoch 5/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1269 - accuracy: 0.6111 - IoU_coef: 0.1269 - val_loss: -0.0842 - val_accuracy: 0.0526 - val_IoU_coef: 0.0842
# Epoch 6/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1314 - accuracy: 0.6293 - IoU_coef: 0.1314 - val_loss: -0.0834 - val_accuracy: 0.0566 - val_IoU_coef: 0.0834
# Epoch 7/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1354 - accuracy: 0.6621 - IoU_coef: 0.1354 - val_loss: -0.0832 - val_accuracy: 0.0643 - val_IoU_coef: 0.0832
# Epoch 8/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1387 - accuracy: 0.6767 - IoU_coef: 0.1387 - val_loss: -0.0832 - val_accuracy: 0.0703 - val_IoU_coef: 0.0832
# Epoch 9/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1410 - accuracy: 0.6800 - IoU_coef: 0.1410 - val_loss: -0.0833 - val_accuracy: 0.0729 - val_IoU_coef: 0.0833
# Epoch 10/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1433 - accuracy: 0.6879 - IoU_coef: 0.1433 - val_loss: -0.0834 - val_accuracy: 0.0744 - val_IoU_coef: 0.0834
# Epoch 25/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1550 - accuracy: 0.7682 - IoU_coef: 0.1550 - val_loss: -0.0823 - val_accuracy: 0.0530 - val_IoU_coef: 0.0823
# Epoch 26/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1555 - accuracy: 0.7688 - IoU_coef: 0.1555 - val_loss: -0.0822 - val_accuracy: 0.0528 - val_IoU_coef: 0.0822
# Epoch 27/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1559 - accuracy: 0.7684 - IoU_coef: 0.1559 - val_loss: -0.0822 - val_accuracy: 0.0524 - val_IoU_coef: 0.0822
# Epoch 28/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1562 - accuracy: 0.7697 - IoU_coef: 0.1562 - val_loss: -0.0821 - val_accuracy: 0.0518 - val_IoU_coef: 0.0821
# Epoch 29/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1566 - accuracy: 0.7724 - IoU_coef: 0.1566 - val_loss: -0.0820 - val_accuracy: 0.0513 - val_IoU_coef: 0.0820
# Epoch 30/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1571 - accuracy: 0.7764 - IoU_coef: 0.1571 - val_loss: -0.0821 - val_accuracy: 0.0513 - val_IoU_coef: 0.0821
# Epoch 31/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1574 - accuracy: 0.7800 - IoU_coef: 0.1574 - val_loss: -0.0822 - val_accuracy: 0.0520 - val_IoU_coef: 0.0822
# Epoch 32/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1576 - accuracy: 0.7819 - IoU_coef: 0.1576 - val_loss: -0.0823 - val_accuracy: 0.0530 - val_IoU_coef: 0.0823
# Epoch 33/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1581 - accuracy: 0.7840 - IoU_coef: 0.1581 - val_loss: -0.0824 - val_accuracy: 0.0539 - val_IoU_coef: 0.0824
# Epoch 34/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1584 - accuracy: 0.7841 - IoU_coef: 0.1584 - val_loss: -0.0825 - val_accuracy: 0.0546 - val_IoU_coef: 0.0825
# Epoch 35/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1587 - accuracy: 0.7846 - IoU_coef: 0.1587 - val_loss: -0.0826 - val_accuracy: 0.0550 - val_IoU_coef: 0.0826
# Epoch 36/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1592 - accuracy: 0.7866 - IoU_coef: 0.1592 - val_loss: -0.0827 - val_accuracy: 0.0559 - val_IoU_coef: 0.0827
# Epoch 37/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1595 - accuracy: 0.7880 - IoU_coef: 0.1595 - val_loss: -0.0830 - val_accuracy: 0.0578 - val_IoU_coef: 0.0830
# Epoch 38/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1596 - accuracy: 0.7891 - IoU_coef: 0.1596 - val_loss: -0.0832 - val_accuracy: 0.0597 - val_IoU_coef: 0.0832
# Epoch 39/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1600 - accuracy: 0.7929 - IoU_coef: 0.1600 - val_loss: -0.0836 - val_accuracy: 0.0622 - val_IoU_coef: 0.0836
# Epoch 40/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1604 - accuracy: 0.7930 - IoU_coef: 0.1604 - val_loss: -0.0839 - val_accuracy: 0.0644 - val_IoU_coef: 0.0839
# Epoch 41/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1607 - accuracy: 0.7924 - IoU_coef: 0.1607 - val_loss: -0.0842 - val_accuracy: 0.0663 - val_IoU_coef: 0.0842
# Epoch 42/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1611 - accuracy: 0.7941 - IoU_coef: 0.1611 - val_loss: -0.0849 - val_accuracy: 0.0704 - val_IoU_coef: 0.0849
# Epoch 43/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1613 - accuracy: 0.7938 - IoU_coef: 0.1613 - val_loss: -0.0855 - val_accuracy: 0.0759 - val_IoU_coef: 0.0855
# Epoch 44/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1616 - accuracy: 0.7971 - IoU_coef: 0.1616 - val_loss: -0.0864 - val_accuracy: 0.0850 - val_IoU_coef: 0.0864
# Epoch 45/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1619 - accuracy: 0.7988 - IoU_coef: 0.1619 - val_loss: -0.0872 - val_accuracy: 0.0964 - val_IoU_coef: 0.0872
# Epoch 46/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1621 - accuracy: 0.7994 - IoU_coef: 0.1621 - val_loss: -0.0880 - val_accuracy: 0.1081 - val_IoU_coef: 0.0880
# Epoch 47/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1624 - accuracy: 0.7995 - IoU_coef: 0.1624 - val_loss: -0.0882 - val_accuracy: 0.1075 - val_IoU_coef: 0.0882
# Epoch 48/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1627 - accuracy: 0.8030 - IoU_coef: 0.1627 - val_loss: -0.0893 - val_accuracy: 0.1267 - val_IoU_coef: 0.0893
# Epoch 49/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1630 - accuracy: 0.8017 - IoU_coef: 0.1630 - val_loss: -0.0898 - val_accuracy: 0.1338 - val_IoU_coef: 0.0898
# Epoch 50/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1631 - accuracy: 0.8066 - IoU_coef: 0.1631 - val_loss: -0.0914 - val_accuracy: 0.2145 - val_IoU_coef: 0.0914
# Epoch 51/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1634 - accuracy: 0.8023 - IoU_coef: 0.1634 - val_loss: -0.0929 - val_accuracy: 0.1974 - val_IoU_coef: 0.0929
# Epoch 52/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1638 - accuracy: 0.8073 - IoU_coef: 0.1638 - val_loss: -0.0938 - val_accuracy: 0.1836 - val_IoU_coef: 0.0938
# Epoch 53/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1639 - accuracy: 0.8094 - IoU_coef: 0.1639 - val_loss: -0.0957 - val_accuracy: 0.2415 - val_IoU_coef: 0.0957
# Epoch 54/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1642 - accuracy: 0.8058 - IoU_coef: 0.1642 - val_loss: -0.0960 - val_accuracy: 0.2556 - val_IoU_coef: 0.0960
# Epoch 55/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1646 - accuracy: 0.8076 - IoU_coef: 0.1646 - val_loss: -0.0957 - val_accuracy: 0.2247 - val_IoU_coef: 0.0957
# Epoch 56/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1646 - accuracy: 0.8111 - IoU_coef: 0.1646 - val_loss: -0.0973 - val_accuracy: 0.2563 - val_IoU_coef: 0.0973
# Epoch 57/150
# ...
# Epoch 64/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1668 - accuracy: 0.8185 - IoU_coef: 0.1668 - val_loss: -0.1141 - val_accuracy: 0.5537 - val_IoU_coef: 0.1141
# Epoch 65/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1671 - accuracy: 0.8198 - IoU_coef: 0.1671 - val_loss: -0.1162 - val_accuracy: 0.5590 - val_IoU_coef: 0.1162
# Epoch 66/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1673 - accuracy: 0.8194 - IoU_coef: 0.1673 - val_loss: -0.1189 - val_accuracy: 0.6414 - val_IoU_coef: 0.1189
# Epoch 67/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1676 - accuracy: 0.8166 - IoU_coef: 0.1676 - val_loss: -0.1215 - val_accuracy: 0.6482 - val_IoU_coef: 0.1215
# Epoch 68/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1678 - accuracy: 0.8188 - IoU_coef: 0.1678 - val_loss: -0.1232 - val_accuracy: 0.6634 - val_IoU_coef: 0.1232
# Epoch 69/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1681 - accuracy: 0.8221 - IoU_coef: 0.1681 - val_loss: -0.1265 - val_accuracy: 0.7619 - val_IoU_coef: 0.1265
# Epoch 70/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1682 - accuracy: 0.8214 - IoU_coef: 0.1682 - val_loss: -0.1280 - val_accuracy: 0.7590 - val_IoU_coef: 0.1280
# Epoch 71/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1685 - accuracy: 0.8266 - IoU_coef: 0.1685 - val_loss: -0.1295 - val_accuracy: 0.7642 - val_IoU_coef: 0.1295
# Epoch 72/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1688 - accuracy: 0.8262 - IoU_coef: 0.1688 - val_loss: -0.1307 - val_accuracy: 0.7790 - val_IoU_coef: 0.1307
# Epoch 73/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1689 - accuracy: 0.8212 - IoU_coef: 0.1689 - val_loss: -0.1315 - val_accuracy: 0.7566 - val_IoU_coef: 0.1315
# Epoch 145/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1842 - accuracy: 0.8587 - IoU_coef: 0.1842 - val_loss: -0.1341 - val_accuracy: 0.8685 - val_IoU_coef: 0.1341
# Epoch 146/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1844 - accuracy: 0.8604 - IoU_coef: 0.1844 - val_loss: -0.1356 - val_accuracy: 0.8653 - val_IoU_coef: 0.1356
# Epoch 147/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1847 - accuracy: 0.8587 - IoU_coef: 0.1847 - val_loss: -0.1348 - val_accuracy: 0.8672 - val_IoU_coef: 0.1348
# Epoch 148/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1848 - accuracy: 0.8594 - IoU_coef: 0.1848 - val_loss: -0.1328 - val_accuracy: 0.8712 - val_IoU_coef: 0.1328
# Epoch 149/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1850 - accuracy: 0.8601 - IoU_coef: 0.1850 - val_loss: -0.1319 - val_accuracy: 0.8729 - val_IoU_coef: 0.1319
# Epoch 150/150
# 1/1 [==============================] - 1s 1s/step - loss: -0.1852 - accuracy: 0.8596 - IoU_coef: 0.1852 - val_loss: -0.1319 - val_accuracy: 0.8734 - val_IoU_coef: 0.1319

# %% [markdown]
# ## test

# %%
import os
import cv2
import numpy as np
import skimage.io
from matplotlib import pyplot as plt
from patchify import patchify, unpatchify
np.random.seed(0)

# CLAHE
def clahe_equalized(imgs):    
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))    
    imgs_equalized = clahe.apply(imgs)
    return imgs_equalized

patch_size = 512

#loading model architectures
# from model import unetmodel, residualunet, attentionunet, attention_residualunet
from tensorflow.keras.optimizers import Adam
# from evaluation_metrics import IoU_coef,IoU_loss

IMG_HEIGHT = patch_size
IMG_WIDTH = patch_size
IMG_CHANNELS = 1

input_shape = (IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS)

model = attentionunet(input_shape)#unetmodel(input_shape) #/residualunet(input_shape)/attentionunet(input_shape)/attention_residualunet(input_shape) 
model.compile(optimizer = Adam(lr = 1e-3), loss= IoU_loss, metrics= ['accuracy', IoU_coef])
model.load_weights('/content/drive/MyDrive/Dataset/new_data/files/attention_model_150_epochs.hdf5') #loading weights


path1 = '/content/drive/MyDrive/Dataset/DRIVE/test/images'    #test dataset images directory path
path2 = '/content/drive/MyDrive/Dataset/DRIVE/test/manual'     #test dataset mask directory path


from sklearn.metrics import jaccard_score,confusion_matrix

testimg = []
ground_truth = []
prediction = []
global_IoU = []
global_accuracy = []

testimages = sorted(os.listdir(path1))
testmasks =  sorted(os.listdir(path2))

for idx, image_name in enumerate(testimages):  
   if image_name.endswith(".tif"):  
      predicted_patches = []
      test_img = tiff.imread(path1+"/"+image_name)
     
      test = test_img[:,:,1] #selecting green channel
      test = clahe_equalized(test) #applying CLAHE
      SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
      SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
      test = cv2.resize(test, (SIZE_X, SIZE_Y))
      testimg.append(test)           
      test = np.array(test)

      patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

      for i in range(patches.shape[0]):
                for j in range(patches.shape[1]):
                  single_patch = patches[i,j,:,:]
                  single_patch_norm = (single_patch.astype('float32')) / 255.
                  single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
                  single_patch_input = np.expand_dims(single_patch_norm, 0)
                  single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
                  predicted_patches.append(single_patch_prediction)
      predicted_patches = np.array(predicted_patches)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
      reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img
      prediction.append(reconstructed_image) 

      groundtruth=[]
      groundtruth = skimage.io.imread(path2+'/'+testmasks[idx]) #reading mask of the test img      
      SIZE_X = (groundtruth.shape[1]//patch_size)*patch_size 
      SIZE_Y = (groundtruth.shape[0]//patch_size)*patch_size  
      groundtruth = cv2.resize(groundtruth, (SIZE_X, SIZE_Y))  
      ground_truth.append(groundtruth)

      y_true = groundtruth
      y_pred = reconstructed_image
      labels = [0, 1]
      IoU = []
      for label in labels:
          jaccard = jaccard_score(y_pred.flatten(),y_true.flatten(), pos_label=label, average='weighted')
          IoU.append(jaccard)
      IoU = np.mean(IoU) #jacard/IoU of single image
      global_IoU.append(IoU)

      cm=[]
      accuracy = []
      cm = confusion_matrix(y_true.flatten(),y_pred.flatten(), labels=[0, 1])
      accuracy = (cm[0,0]+cm[1,1])/(cm[0,0]+cm[0,1]+cm[1,0]+cm[1,1]) #accuracy of single image
      global_accuracy.append(accuracy)


avg_acc =  np.mean(global_accuracy)
mean_IoU = np.mean(global_IoU)

print('Average accuracy is',avg_acc)
print('mean IoU is',mean_IoU)


#checking segmentation results
import random
test_img_number = random.randint(0, len(testimg))
plt.figure(figsize=(20, 18))
plt.subplot(231)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(testimg[test_img_number])
plt.subplot(232)
plt.title('Ground Truth')
plt.xticks([])
plt.yticks([])
plt.imshow(ground_truth[test_img_number],cmap='gray')
plt.subplot(233)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(prediction[test_img_number],cmap='gray')

plt.show()



# #prediction on single image
from datetime import datetime 
reconstructed_image = []
test_img = skimage.io.imread('/content/drive/MyDrive/Dataset/DRIVE/test/images/02_test.tif') #test image

predicted_patches = []
start = datetime.now()   

test = test_img[:,:,1] #selecting green channel
test = clahe_equalized(test) #applying CLAHE
SIZE_X = (test_img.shape[1]//patch_size)*patch_size #getting size multiple of patch size
SIZE_Y = (test_img.shape[0]//patch_size)*patch_size #getting size multiple of patch size
test = cv2.resize(test, (SIZE_X, SIZE_Y))        
test = np.array(test)
patches = patchify(test, (patch_size, patch_size), step=patch_size) #create patches(patch_sizexpatch_sizex1)

for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_norm = (single_patch.astype('float32')) / 255.
          single_patch_norm = np.expand_dims(np.array(single_patch_norm), axis=-1)
          single_patch_input = np.expand_dims(single_patch_norm, 0)
          single_patch_prediction = (model.predict(single_patch_input)[0,:,:,0] > 0.5).astype(np.uint8) #predict on single patch
          predicted_patches.append(single_patch_prediction)
predicted_patches = np.array(predicted_patches)
predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patch_size,patch_size) )
reconstructed_image = unpatchify(predicted_patches_reshaped, test.shape) #join patches to form whole img

stop = datetime.now()
print('Execution time: ',(stop-start)) #computation time

plt.subplot(121)
plt.title('Test Image')
plt.xticks([])
plt.yticks([])
plt.imshow(test_img)
plt.subplot(122)
plt.title('Prediction')
plt.xticks([])
plt.yticks([])
plt.imshow(reconstructed_image,cmap='gray')

plt.show()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 512, 512, 1  0           []
#                                 )]
#
#  conv2d_136 (Conv2D)            (None, 512, 512, 16  160         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_100 (Batch  (None, 512, 512, 16  64         ['conv2d_136[0][0]']
#  Normalization)                 )
#
#  activation_112 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_100[0][0]']
#                                 )
#
#  dropout_36 (Dropout)           (None, 512, 512, 16  0           ['activation_112[0][0]']
#                                 )
#
#  conv2d_137 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_36[0][0]']
#                                 )
#
#  batch_normalization_101 (Batch  (None, 512, 512, 16  64         ['conv2d_137[0][0]']
#  Normalization)                 )
#
#  activation_113 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_101[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 256, 256, 16  0          ['activation_113[0][0]']
#  )                              )
#
#  conv2d_138 (Conv2D)            (None, 256, 256, 32  4640        ['max_pooling2d_16[0][0]']
#                                 )
#
#  batch_normalization_102 (Batch  (None, 256, 256, 32  128        ['conv2d_138[0][0]']
#  Normalization)                 )
#
#  activation_114 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_102[0][0]']
#                                 )
#
#  dropout_37 (Dropout)           (None, 256, 256, 32  0           ['activation_114[0][0]']
#                                 )
#
#  conv2d_139 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_37[0][0]']
#                                 )
#
#  batch_normalization_103 (Batch  (None, 256, 256, 32  128        ['conv2d_139[0][0]']
#  Normalization)                 )
#
#  activation_115 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_103[0][0]']
#                                 )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 128, 128, 32  0          ['activation_115[0][0]']
#  )                              )
#
#  conv2d_140 (Conv2D)            (None, 128, 128, 64  18496       ['max_pooling2d_17[0][0]']
#                                 )
#
#  batch_normalization_104 (Batch  (None, 128, 128, 64  256        ['conv2d_140[0][0]']
#  Normalization)                 )
#
#  activation_116 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_104[0][0]']
#                                 )
#
#  dropout_38 (Dropout)           (None, 128, 128, 64  0           ['activation_116[0][0]']
#                                 )
#
#  conv2d_141 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_38[0][0]']
#                                 )
#
#  batch_normalization_105 (Batch  (None, 128, 128, 64  256        ['conv2d_141[0][0]']
#  Normalization)                 )
#
#  activation_117 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_105[0][0]']
#                                 )
#
#  max_pooling2d_18 (MaxPooling2D  (None, 64, 64, 64)  0           ['activation_117[0][0]']
#  )
#
#  conv2d_142 (Conv2D)            (None, 64, 64, 128)  73856       ['max_pooling2d_18[0][0]']
#
#  batch_normalization_106 (Batch  (None, 64, 64, 128)  512        ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_118 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_106[0][0]']
#
#  dropout_39 (Dropout)           (None, 64, 64, 128)  0           ['activation_118[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_39[0][0]']
#
#  batch_normalization_107 (Batch  (None, 64, 64, 128)  512        ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_119 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_107[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 32, 32, 128)  0          ['activation_119[0][0]']
#  )
#
#  conv2d_144 (Conv2D)            (None, 32, 32, 256)  295168      ['max_pooling2d_19[0][0]']
#
#  batch_normalization_108 (Batch  (None, 32, 32, 256)  1024       ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_108[0][0]']
#
#  dropout_40 (Dropout)           (None, 32, 32, 256)  0           ['activation_120[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 32, 32, 256)  590080      ['dropout_40[0][0]']
#
#  batch_normalization_109 (Batch  (None, 32, 32, 256)  1024       ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 32, 32, 256)  0           ['batch_normalization_109[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 32, 32, 128)  32896       ['activation_121[0][0]']
#
#  batch_normalization_110 (Batch  (None, 32, 32, 128)  512        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 32, 32, 128)  0           ['batch_normalization_110[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 32, 32, 128)  16512       ['activation_122[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 32, 32, 128)  147584     ['conv2d_148[0][0]']
#  nspose)
#
#  conv2d_147 (Conv2D)            (None, 32, 32, 128)  65664       ['activation_119[0][0]']
#
#  add_12 (Add)                   (None, 32, 32, 128)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_147[0][0]']
#
#  activation_123 (Activation)    (None, 32, 32, 128)  0           ['add_12[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 32, 32, 1)    129         ['activation_123[0][0]']
#
#  activation_124 (Activation)    (None, 32, 32, 1)    0           ['conv2d_149[0][0]']
#
#  up_sampling2d_28 (UpSampling2D  (None, 64, 64, 1)   0           ['activation_124[0][0]']
#  )
#
#  lambda_12 (Lambda)             (None, 64, 64, 128)  0           ['up_sampling2d_28[0][0]']
#
#  multiply_12 (Multiply)         (None, 64, 64, 128)  0           ['lambda_12[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 64, 64, 128)  16512       ['multiply_12[0][0]']
#
#  up_sampling2d_29 (UpSampling2D  (None, 64, 64, 256)  0          ['activation_121[0][0]']
#  )
#
#  batch_normalization_111 (Batch  (None, 64, 64, 128)  512        ['conv2d_150[0][0]']
#  Normalization)
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 384)  0           ['up_sampling2d_29[0][0]',
#                                                                   'batch_normalization_111[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 64, 64, 128)  442496      ['concatenate_16[0][0]']
#
#  batch_normalization_112 (Batch  (None, 64, 64, 128)  512        ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_112[0][0]']
#
#  dropout_41 (Dropout)           (None, 64, 64, 128)  0           ['activation_125[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 64, 64, 128)  147584      ['dropout_41[0][0]']
#
#  batch_normalization_113 (Batch  (None, 64, 64, 128)  512        ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 64, 64, 128)  0           ['batch_normalization_113[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 64, 64, 64)   8256        ['activation_126[0][0]']
#
#  batch_normalization_114 (Batch  (None, 64, 64, 64)  256         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 64, 64, 64)   0           ['batch_normalization_114[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 64, 64, 64)   4160        ['activation_127[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 64, 64, 64)  36928       ['conv2d_155[0][0]']
#  nspose)
#
#  conv2d_154 (Conv2D)            (None, 64, 64, 64)   16448       ['activation_117[0][0]']
#
#  add_13 (Add)                   (None, 64, 64, 64)   0           ['conv2d_transpose_13[0][0]',
#                                                                   'conv2d_154[0][0]']
#
#  activation_128 (Activation)    (None, 64, 64, 64)   0           ['add_13[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 64, 64, 1)    65          ['activation_128[0][0]']
#
#  activation_129 (Activation)    (None, 64, 64, 1)    0           ['conv2d_156[0][0]']
#
#  up_sampling2d_30 (UpSampling2D  (None, 128, 128, 1)  0          ['activation_129[0][0]']
#  )
#
#  lambda_13 (Lambda)             (None, 128, 128, 64  0           ['up_sampling2d_30[0][0]']
#                                 )
#
#  multiply_13 (Multiply)         (None, 128, 128, 64  0           ['lambda_13[0][0]',
#                                 )                                 'activation_117[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 128, 128, 64  4160        ['multiply_13[0][0]']
#                                 )
#
#  up_sampling2d_31 (UpSampling2D  (None, 128, 128, 12  0          ['activation_126[0][0]']
#  )                              8)
#
#  batch_normalization_115 (Batch  (None, 128, 128, 64  256        ['conv2d_157[0][0]']
#  Normalization)                 )
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 19  0           ['up_sampling2d_31[0][0]',
#                                 2)                                'batch_normalization_115[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 128, 128, 64  110656      ['concatenate_17[0][0]']
#                                 )
#
#  batch_normalization_116 (Batch  (None, 128, 128, 64  256        ['conv2d_158[0][0]']
#  Normalization)                 )
#
#  activation_130 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_116[0][0]']
#                                 )
#
#  dropout_42 (Dropout)           (None, 128, 128, 64  0           ['activation_130[0][0]']
#                                 )
#
#  conv2d_159 (Conv2D)            (None, 128, 128, 64  36928       ['dropout_42[0][0]']
#                                 )
#
#  batch_normalization_117 (Batch  (None, 128, 128, 64  256        ['conv2d_159[0][0]']
#  Normalization)                 )
#
#  activation_131 (Activation)    (None, 128, 128, 64  0           ['batch_normalization_117[0][0]']
#                                 )
#
#  conv2d_160 (Conv2D)            (None, 128, 128, 32  2080        ['activation_131[0][0]']
#                                 )
#
#  batch_normalization_118 (Batch  (None, 128, 128, 32  128        ['conv2d_160[0][0]']
#  Normalization)                 )
#
#  activation_132 (Activation)    (None, 128, 128, 32  0           ['batch_normalization_118[0][0]']
#                                 )
#
#  conv2d_162 (Conv2D)            (None, 128, 128, 32  1056        ['activation_132[0][0]']
#                                 )
#
#  conv2d_transpose_14 (Conv2DTra  (None, 128, 128, 32  9248       ['conv2d_162[0][0]']
#  nspose)                        )
#
#  conv2d_161 (Conv2D)            (None, 128, 128, 32  4128        ['activation_115[0][0]']
#                                 )
#
#  add_14 (Add)                   (None, 128, 128, 32  0           ['conv2d_transpose_14[0][0]',
#                                 )                                 'conv2d_161[0][0]']
#
#  activation_133 (Activation)    (None, 128, 128, 32  0           ['add_14[0][0]']
#                                 )
#
#  conv2d_163 (Conv2D)            (None, 128, 128, 1)  33          ['activation_133[0][0]']
#
#  activation_134 (Activation)    (None, 128, 128, 1)  0           ['conv2d_163[0][0]']
#
#  up_sampling2d_32 (UpSampling2D  (None, 256, 256, 1)  0          ['activation_134[0][0]']
#  )
#
#  lambda_14 (Lambda)             (None, 256, 256, 32  0           ['up_sampling2d_32[0][0]']
#                                 )
#
#  multiply_14 (Multiply)         (None, 256, 256, 32  0           ['lambda_14[0][0]',
#                                 )                                 'activation_115[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 256, 256, 32  1056        ['multiply_14[0][0]']
#                                 )
#
#  up_sampling2d_33 (UpSampling2D  (None, 256, 256, 64  0          ['activation_131[0][0]']
#  )                              )
#
#  batch_normalization_119 (Batch  (None, 256, 256, 32  128        ['conv2d_164[0][0]']
#  Normalization)                 )
#
#  concatenate_18 (Concatenate)   (None, 256, 256, 96  0           ['up_sampling2d_33[0][0]',
#                                 )                                 'batch_normalization_119[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 256, 256, 32  27680       ['concatenate_18[0][0]']
#                                 )
#
#  batch_normalization_120 (Batch  (None, 256, 256, 32  128        ['conv2d_165[0][0]']
#  Normalization)                 )
#
#  activation_135 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_120[0][0]']
#                                 )
#
#  dropout_43 (Dropout)           (None, 256, 256, 32  0           ['activation_135[0][0]']
#                                 )
#
#  conv2d_166 (Conv2D)            (None, 256, 256, 32  9248        ['dropout_43[0][0]']
#                                 )
#
#  batch_normalization_121 (Batch  (None, 256, 256, 32  128        ['conv2d_166[0][0]']
#  Normalization)                 )
#
#  activation_136 (Activation)    (None, 256, 256, 32  0           ['batch_normalization_121[0][0]']
#                                 )
#
#  conv2d_167 (Conv2D)            (None, 256, 256, 16  528         ['activation_136[0][0]']
#                                 )
#
#  batch_normalization_122 (Batch  (None, 256, 256, 16  64         ['conv2d_167[0][0]']
#  Normalization)                 )
#
#  activation_137 (Activation)    (None, 256, 256, 16  0           ['batch_normalization_122[0][0]']
#                                 )
#
#  conv2d_169 (Conv2D)            (None, 256, 256, 16  272         ['activation_137[0][0]']
#                                 )
#
#  conv2d_transpose_15 (Conv2DTra  (None, 256, 256, 16  2320       ['conv2d_169[0][0]']
#  nspose)                        )
#
#  conv2d_168 (Conv2D)            (None, 256, 256, 16  1040        ['activation_113[0][0]']
#                                 )
#
#  add_15 (Add)                   (None, 256, 256, 16  0           ['conv2d_transpose_15[0][0]',
#                                 )                                 'conv2d_168[0][0]']
#
#  activation_138 (Activation)    (None, 256, 256, 16  0           ['add_15[0][0]']
#                                 )
#
#  conv2d_170 (Conv2D)            (None, 256, 256, 1)  17          ['activation_138[0][0]']
#
#  activation_139 (Activation)    (None, 256, 256, 1)  0           ['conv2d_170[0][0]']
#
#  up_sampling2d_34 (UpSampling2D  (None, 512, 512, 1)  0          ['activation_139[0][0]']
#  )
#
#  lambda_15 (Lambda)             (None, 512, 512, 16  0           ['up_sampling2d_34[0][0]']
#                                 )
#
#  multiply_15 (Multiply)         (None, 512, 512, 16  0           ['lambda_15[0][0]',
#                                 )                                 'activation_113[0][0]']
#
#  conv2d_171 (Conv2D)            (None, 512, 512, 16  272         ['multiply_15[0][0]']
#                                 )
#
#  up_sampling2d_35 (UpSampling2D  (None, 512, 512, 32  0          ['activation_136[0][0]']
#  )                              )
#
#  batch_normalization_123 (Batch  (None, 512, 512, 16  64         ['conv2d_171[0][0]']
#  Normalization)                 )
#
#  concatenate_19 (Concatenate)   (None, 512, 512, 48  0           ['up_sampling2d_35[0][0]',
#                                 )                                 'batch_normalization_123[0][0]']
#
#  conv2d_172 (Conv2D)            (None, 512, 512, 16  6928        ['concatenate_19[0][0]']
#                                 )
#
#  batch_normalization_124 (Batch  (None, 512, 512, 16  64         ['conv2d_172[0][0]']
#  Normalization)                 )
#
#  activation_140 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_124[0][0]']
#                                 )
#
#  dropout_44 (Dropout)           (None, 512, 512, 16  0           ['activation_140[0][0]']
#                                 )
#
#  conv2d_173 (Conv2D)            (None, 512, 512, 16  2320        ['dropout_44[0][0]']
#                                 )
#
#  batch_normalization_125 (Batch  (None, 512, 512, 16  64         ['conv2d_173[0][0]']
#  Normalization)                 )
#
#  activation_141 (Activation)    (None, 512, 512, 16  0           ['batch_normalization_125[0][0]']
#                                 )
#
#  conv2d_174 (Conv2D)            (None, 512, 512, 1)  17          ['activation_141[0][0]']
#
#  batch_normalization_126 (Batch  (None, 512, 512, 1)  4          ['conv2d_174[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 512, 512, 1)  0           ['batch_normalization_126[0][0]']
#
# ==================================================================================================
# Total params: 2,341,513
# Trainable params: 2,337,607
# Non-trainable params: 3,906
# __________________________________________________________________________________________________
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# 1/1 [==============================] - 1s 654ms/step
# 1/1 [==============================] - 0s 23ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 27ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 27ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 24ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 26ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 25ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 27ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 27ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 28ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 23ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# Average accuracy is 0.8922458692985344
# mean IoU is 0.7094389878095876
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1370: UserWarning: Note that pos_label (set to 0) is ignored when average != 'binary' (got 'weighted'). You may use labels=[pos_label] to specify a single positive class.
#   warnings.warn(
# 1/1 [==============================] - 0s 30ms/step
# Execution time:  0:00:00.126679

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
